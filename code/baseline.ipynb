# %% [markdown]
# # **CondLaneNet: a Top-to-down Lane Detection Framework Based on Conditional Convolution**
#
# [Official GitHub repository](https://github.com/aliyun/conditional-lane-detection)

# %% [markdown]
# ## Connect Google Drive and set working folder

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/University/Second_year/AML/AML\ -\ Final\ Project/data
# Out:
# /gdrive/.shortcut-targets-by-id/1bKkOxnV3HlM0klPcoIk5ik84I4xDxYs7/AML - Final Project/data
